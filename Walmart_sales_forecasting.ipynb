# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from IPython.core.display import display, HTML
#this is a test

# %%
# !git init Walmart_sales_forecasting
# Out:
# Initialized empty Git repository in /content/Walmart_sales_forecasting/.git/

# %%
# %cd Walmart_sales_forecasting/
# Out:
# /content/Walmart_sales_forecasting

# %%
# !git add .

# %%
# !git status

# %%
feature_dataset = pd.read_csv("/content/drive/MyDrive/Walmart_forecasting/features.csv")
feature_dataset_df = pd.DataFrame(feature_dataset)

# %%
feature_dataset
# Out:
#       Store        Date  Temperature  ...         CPI  Unemployment  IsHoliday
# 0         1  2010-02-05        42.31  ...  211.096358         8.106      False
# 1         1  2010-02-12        38.51  ...  211.242170         8.106       True
# 2         1  2010-02-19        39.93  ...  211.289143         8.106      False
# 3         1  2010-02-26        46.63  ...  211.319643         8.106      False
# 4         1  2010-03-05        46.50  ...  211.350143         8.106      False
# ...     ...         ...          ...  ...         ...           ...        ...
# 8185     45  2013-06-28        76.05  ...         NaN           NaN      False
# 8186     45  2013-07-05        77.50  ...         NaN           NaN      False
# 8187     45  2013-07-12        79.37  ...         NaN           NaN      False
# 8188     45  2013-07-19        82.84  ...         NaN           NaN      False
# 8189     45  2013-07-26        76.06  ...         NaN           NaN      False
#
# ...

# %%
train_dataset_df = pd.read_csv("/content/drive/MyDrive/Walmart_forecasting/train.csv")
train_dataset_df = pd.DataFrame(train_dataset_df)
train_dataset_df
# Out:
#         Store  Dept        Date  Weekly_Sales  IsHoliday
# 0           1     1  2010-02-05      24924.50      False
# 1           1     1  2010-02-12      46039.49       True
# 2           1     1  2010-02-19      41595.55      False
# 3           1     1  2010-02-26      19403.54      False
# 4           1     1  2010-03-05      21827.90      False
# ...       ...   ...         ...           ...        ...
# 421565     45    98  2012-09-28        508.37      False
# 421566     45    98  2012-10-05        628.10      False
# 421567     45    98  2012-10-12       1061.02      False
# 421568     45    98  2012-10-19        760.01      False
# 421569     45    98  2012-10-26       1076.80      False
#
# [421570 rows x 5 columns]

# %%
complete_sales_dataset_df = feature_dataset_df.join(train_dataset_df['Weekly_Sales'])
complete_sales_dataset_df
# Out:
#       Store        Date  Temperature  ...  Unemployment  IsHoliday  Weekly_Sales
# 0         1  2010-02-05        42.31  ...         8.106      False      24924.50
# 1         1  2010-02-12        38.51  ...         8.106       True      46039.49
# 2         1  2010-02-19        39.93  ...         8.106      False      41595.55
# 3         1  2010-02-26        46.63  ...         8.106      False      19403.54
# 4         1  2010-03-05        46.50  ...         8.106      False      21827.90
# ...     ...         ...          ...  ...           ...        ...           ...
# 8185     45  2013-06-28        76.05  ...           NaN      False      16501.99
# 8186     45  2013-07-05        77.50  ...           NaN      False      16269.33
# 8187     45  2013-07-12        79.37  ...           NaN      False      16911.18
# 8188     45  2013-07-19        82.84  ...           NaN      False      20426.69
# 8189     45  2013-07-26        76.06  ...           NaN      False      19404.90
#
# ...

# %% [markdown]
# **Data VIsualization**

# %%
g = sns.PairGrid(complete_sales_dataset_df)
g.map(sns.scatterplot)

# %%
jsonstr = complete_sales_dataset_df.to_json(orient='records')
HTML_TEMPLATE = """
<script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"></script>
<link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/1.0.0/facets-dist/facets-jupyter.html">
<facets-dive id="elem" height="600"></facets-dive>
<script>
var data = {jsonstr};
document.querySelector("#elem").data = data;
</script>"""
html = HTML_TEMPLATE.format(jsonstr=jsonstr)
display(HTML(html))
# Out:
# Output hidden; open in https://colab.research.google.com to view.
